# %%
using Pkg
Pkg.activate("../Project.toml")

include("../LogLoss/RealRealHighDimension.jl")
include("imputation.jl");
include("imputationUtils.jl")
using JLD2
using DataFrames
using StatProfilerHTML
using BenchmarkTools
# Out:
#   Activating project at `~/Documents/QML Project/QuantumInspiredML`

# %%
# svpath_slb = "../Data/ecg200/mps_saves/sahand_legendre_ns_d20_chi100_range.jld2" #legendre_no_norm_ns_d16_chi60.jld2" #legendreNN2_ns_d8_chi35.jld2"
svpath_sl = "../Data/ecg200/mps_saves/sahand_legendre_ns_d20_chi100.jld2"
# svpath_leg = "../Data/ecg200/mps_saves/legendre_no_norm10_ns_d20_chi100.jld2" #legendre_no_norm_ns_d16_chi60.jld2" #legendreNN2_ns_d8_chi35.jld2"

dloc =  "../Data/ecg200/datasets/ecg200.jld2"



f = jldopen(dloc, "r")
    X_train = read(f, "X_train")
    y_train = read(f, "y_train")
    X_test = read(f, "X_test")
    y_test = read(f, "y_test")
close(f)



###################################3

f = jldopen(svpath_sl, "r")
    mps_sl = read(f, "mps")
    opts_sl = read(f, "opts")
close(f)

opts_sl, _... = safe_options(opts_sl, nothing, nothing)

fc_sl = load_forecasting_info_variables(mps_sl, X_train, y_train, X_test, y_test, opts_sl);
# Out:
# ++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
#                          Summary:
#
#  - Dataset has 100 training samples and 100 testing samples.
#  - 2 class(es) was detected. Slicing MPS into individual states...
#  - Time independent encoding - Sahand-Legendre Time Independent - detected.
#  - d = 20, chi_max = 100
# Re-encoding the training data to get the encoding arguments...
#
#  Created 2 forecastable struct(s) containing class-wise mps and test samples.

# %%
dx=1E-4
mode_range=(-1,1)
xvals=collect(range(mode_range...; step=dx))
mode_index=Index(opts_sl.d)
xvals_enc= [get_state(x, opts_sl, fc_sl[1].enc_args) for x in xvals]
xvals_enc_it=[ITensor(s, mode_index) for s in xvals_enc];

# %%
class = 1
impute_sites = collect(6:21)
instance_idx = 59 # 4
invert_transform=true
@btime begin 
stats, p1_ns = any_impute_single_timeseries(
    fc_sl, 
    class, 
    instance_idx, 
    impute_sites, 
    :directMedian; 
    invert_transform=invert_transform, 
    NN_baseline=true, 
    X_train=X_train, 
    y_train=y_train, 
    n_baselines=1, 
    plot_fits=true, 
    dx=dx,
    mode_range=mode_range, 
    xvals=xvals, 
    mode_index=mode_index, 
    xvals_enc=xvals_enc, 
    xvals_enc_it=xvals_enc_it
    );
end

pretty_table(stats; header=["Metric", "Value"], header_crayon= crayon"yellow bold", tf = tf_unicode_rounded);
plot(p1_ns...)
# Out:
#   2.051 s (16371748 allocations: 1.75 GiB)
# ╭────────┬──────────╮
# │ Metric │    Value │
# ├────────┼──────────┤
# │    MAE │ 0.637368 │
# │ NN_MAE │ 0.562345 │
# ╰────────┴──────────╯

# %%
include("imputationUtils.jl")
# Out:
# any_impute_ITS_single

# %%
class = 1
impute_sites = collect(6:21)
instance_idx = 59 # 4
invert_transform=true

@btime begin
stats, p1_ns = any_impute_single_timeseries(
    fc_sl, 
    class, 
    instance_idx, 
    impute_sites, 
    :directMedianOpt; 
    invert_transform=invert_transform, 
    NN_baseline=true, 
    X_train=X_train, 
    y_train=y_train, 
    n_baselines=1, 
    plot_fits=true, 
    dx=dx,
    mode_range=mode_range, 
    xvals=xvals, 
    mode_index=mode_index, 
    xvals_enc=xvals_enc, 
    xvals_enc_it=xvals_enc_it
    );
end

pretty_table(stats; header=["Metric", "Value"], header_crayon= crayon"yellow bold", tf = tf_unicode_rounded);
plot(p1_ns...)
# Out:
#   1.963 s (16346037 allocations: 1.42 GiB)
# ╭────────┬──────────╮
# │ Metric │    Value │
# ├────────┼──────────┤
# │    MAE │ 0.637368 │
# │ NN_MAE │ 0.562345 │
# ╰────────┴──────────╯

# %%
include("imputationUtils.jl")
# Out:
# any_impute_ITS_single

# %%
class = 1
impute_sites = collect(6:21)
instance_idx = 59 # 4
invert_transform=true
@btime begin 
stats, p1_ns = any_impute_single_timeseries(
    fc_sl, 
    class, 
    instance_idx, 
    impute_sites, 
    :directMedianOpt; 
    invert_transform=invert_transform, 
    NN_baseline=true, 
    X_train=X_train, 
    y_train=y_train, 
    n_baselines=1, 
    plot_fits=true, 
    dx=dx,
    mode_range=mode_range, 
    xvals=xvals, 
    mode_index=mode_index, 
    xvals_enc=xvals_enc, 
    xvals_enc_it=xvals_enc_it
    );
end

pretty_table(stats; header=["Metric", "Value"], header_crayon= crayon"yellow bold", tf = tf_unicode_rounded);
plot(p1_ns...)
# Out:
#   3.957 s (18428134 allocations: 3.62 GiB)
# ╭────────┬──────────╮
# │ Metric │    Value │
# ├────────┼──────────┤
# │    MAE │ 0.637368 │
# │ NN_MAE │ 0.562345 │
# ╰────────┴──────────╯

# %%
length(impute_sites)
# Out:
# 16

# %%
fc_sl[1]
# Out:
# forecastable(MPS
# [1] ((dim=20|id=690|"Site,n=1"), (dim=15|id=745|"Link,l=1"))
# [2] ((dim=20|id=221|"Site,n=2"), (dim=15|id=745|"Link,l=1"), (dim=89|id=54|"Link,l=2"))
# [3] ((dim=20|id=230|"Site,n=3"), (dim=89|id=54|"Link,l=2"), (dim=100|id=391|"Link,l=3"))
# [4] ((dim=20|id=425|"Site,n=4"), (dim=100|id=391|"Link,l=3"), (dim=100|id=516|"Link,l=4"))
# [5] ((dim=20|id=376|"Site,n=5"), (dim=100|id=516|"Link,l=4"), (dim=100|id=257|"Link,l=5"))
# [6] ((dim=20|id=806|"Site,n=6"), (dim=100|id=257|"Link,l=5"), (dim=100|id=919|"Link,l=6"))
# [7] ((dim=20|id=941|"Site,n=7"), (dim=100|id=919|"Link,l=6"), (dim=100|id=650|"Link,l=7"))
# [8] ((dim=20|id=837|"Site,n=8"), (dim=100|id=650|"Link,l=7"), (dim=100|id=171|"Link,l=8"))
# [9] ((dim=20|id=702|"Site,n=9"), (dim=100|id=171|"Link,l=8"), (dim=100|id=666|"Link,l=9"))
# [10] ((dim=20|id=748|"Site,n=10"), (dim=100|id=666|"Link,l=9"), (dim=100|id=973|"Link,l=10"))
# [11] ((dim=20|id=580|"Site,n=11"), (dim=100|id=973|"Link,l=10"), (dim=100|id=671|"Link,l=11"))
# [12] ((dim=20|id=515|"Site,n=12"), (dim=100|id=671|"Link,l=11"), (dim=100|id=880|"Link,l=12"))
# [13] ((dim=20|id=884|"Site,n=13"), (dim=100|id=880|"Link,l=12"), (dim=100|id=23|"Link,l=13"))
# [14] ((dim=20|id=982|"Site,n=14"), (dim=100|id=23|"Link,l=13"), (dim=100|id=80|"Link,l=14"))
# [15] ((dim=20|id=309|"Site,n=15"), (dim=100|id=80|"Link,l=14"), (dim=100|id=239|"Link,l=15"))
# [16] ((dim=20|id=114|"Site,n=16"), (dim=100|id=239|"Link,l=15"), (dim=100|id=513|"Link,l=16"))
# [17] ((dim=20|id=332|"Site,n=17"), (dim=100|id=513|"Link,l=16"), (dim=100|id=966|"Link,l=17"))
# [18] ((dim=20|id=147|"Site,n=18"), (dim=100|id=966|"Link,l=17"), (dim=100|id=526|"Link,l=18"))
# [19] ((dim=20|id=109|"Site,n=19"), (dim=100|id=526|"Link,l=18"), (dim=100|id=244|"Link,l=19"))
# [20] ((dim=20|id=157|"Site,n=20"), (dim=100|id=244|"Link,l=19"), (dim=100|id=348|"Link,l=20"))
# [21] ((dim=20|id=288|"Site,n=21"), (dim=100|id=348|"Link,l=20"), (dim=100|id=878|"Link,l=21"))
# [22] ((dim=20|id=74|"Site,n=22"), (dim=100|id=878|"Link,l=21"), (dim=100|id=140|"Link,l=22"))
# [23] ((dim=20|id=798|"Site,n=23"), (dim=100|id=140|"Link,l=22"), (dim=100|id=854|"Link,l=23"))
# [24] ((dim=20|id=78|"Site,n=24"), (dim=100|id=854|"Link,l=23"), (dim=100|id=314|"Link,l=24"))
# [25] ((dim=20|id=171|"Site,n=25"), (dim=100|id=314|"Link,l=24"), (dim=100|id=987|"Link,l=25"))
# [26] ((dim=20|id=38|"Site,n=26"), (dim=100|id=987|"Link,l=25"), (dim=100|id=224|"Link,l=26"))
# [27] ((dim=20|id=448|"Site,n=27"), (dim=100|id=224|"Link,l=26"), (dim=100|id=783|"Link,l=27"))
# [28] ((dim=20|id=947|"Site,n=28"), (dim=100|id=783|"Link,l=27"), (dim=100|id=288|"Link,l=28"))
# [29] ((dim=20|id=736|"Site,n=29"), (dim=100|id=288|"Link,l=28"), (dim=100|id=288|"Link,l=29"))
# [30] ((dim=20|id=201|"Site,n=30"), (dim=100|id=288|"Link,l=29"), (dim=100|id=536|"Link,l=30"))
# [31] ((dim=20|id=589|"Site,n=31"), (dim=100|id=536|"Link,l=30"), (dim=100|id=231|"Link,l=31"))
# [32] ((dim=20|id=804|"Site,n=32"), (dim=100|id=231|"Link,l=31"), (dim=100|id=9|"Link,l=32"))
# [33] ((dim=20|id=807|"Site,n=33"), (dim=100|id=9|"Link,l=32"), (dim=100|id=827|"Link,l=33"))
# [34] ((dim=20|id=681|"Site,n=34"), (dim=100|id=827|"Link,l=33"), (dim=100|id=857|"Link,l=34"))
# [35] ((dim=20|id=241|"Site,n=35"), (dim=100|id=857|"Link,l=34"), (dim=100|id=712|"Link,l=35"))
# [36] ((dim=20|id=298|"Site,n=36"), (dim=100|id=712|"Link,l=35"), (dim=100|id=730|"Link,l=36"))
# [37] ((dim=20|id=680|"Site,n=37"), (dim=100|id=730|"Link,l=36"), (dim=100|id=689|"Link,l=37"))
# [38] ((dim=20|id=64|"Site,n=38"), (dim=100|id=689|"Link,l=37"), (dim=100|id=786|"Link,l=38"))
# [39] ((dim=20|id=756|"Site,n=39"), (dim=100|id=786|"Link,l=38"), (dim=100|id=150|"Link,l=39"))
# [40] ((dim=20|id=341|"Site,n=40"), (dim=100|id=150|"Link,l=39"), (dim=100|id=832|"Link,l=40"))
# [41] ((dim=20|id=672|"Site,n=41"), (dim=100|id=832|"Link,l=40"), (dim=100|id=702|"Link,l=41"))
# [42] ((dim=20|id=425|"Site,n=42"), (dim=100|id=702|"Link,l=41"), (dim=100|id=367|"Link,l=42"))
# [43] ((dim=20|id=283|"Site,n=43"), (dim=100|id=367|"Link,l=42"), (dim=100|id=950|"Link,l=43"))
# [44] ((dim=20|id=47|"Site,n=44"), (dim=100|id=950|"Link,l=43"), (dim=100|id=925|"Link,l=44"))
# [45] ((dim=20|id=309|"Site,n=45"), (dim=100|id=925|"Link,l=44"), (dim=100|id=29|"Link,l=45"))
# [46] ((dim=20|id=571|"Site,n=46"), (dim=100|id=29|"Link,l=45"), (dim=100|id=562|"Link,l=46"))
# [47] ((dim=20|id=931|"Site,n=47"), (dim=100|id=562|"Link,l=46"), (dim=100|id=360|"Link,l=47"))
# [48] ((dim=20|id=656|"Site,n=48"), (dim=100|id=360|"Link,l=47"), (dim=100|id=163|"Link,l=48"))
# [49] ((dim=20|id=436|"Site,n=49"), (dim=100|id=163|"Link,l=48"), (dim=100|id=573|"Link,l=49"))
# [50] ((dim=20|id=996|"Site,n=50"), (dim=100|id=573|"Link,l=49"), (dim=100|id=630|"Link,l=50"))
# [51] ((dim=20|id=514|"Site,n=51"), (dim=100|id=630|"Link,l=50"), (dim=100|id=630|"Link,l=51"))
# [52] ((dim=20|id=880|"Site,n=52"), (dim=100|id=630|"Link,l=51"), (dim=100|id=30|"Link,l=52"))
# [53] ((dim=20|id=935|"Site,n=53"), (dim=100|id=30|"Link,l=52"), (dim=100|id=571|"Link,l=53"))
# [54] ((dim=20|id=335|"Site,n=54"), (dim=100|id=571|"Link,l=53"), (dim=100|id=23|"Link,l=54"))
# [55] ((dim=20|id=431|"Site,n=55"), (dim=100|id=23|"Link,l=54"), (dim=100|id=292|"Link,l=55"))
# [56] ((dim=20|id=361|"Site,n=56"), (dim=100|id=292|"Link,l=55"), (dim=100|id=394|"Link,l=56"))
# [57] ((dim=20|id=518|"Site,n=57"), (dim=100|id=394|"Link,l=56"), (dim=100|id=403|"Link,l=57"))
# [58] ((dim=20|id=487|"Site,n=58"), (dim=100|id=403|"Link,l=57"), (dim=100|id=576|"Link,l=58"))
# [59] ((dim=20|id=653|"Site,n=59"), (dim=100|id=576|"Link,l=58"), (dim=100|id=708|"Link,l=59"))
# [60] ((dim=20|id=479|"Site,n=60"), (dim=100|id=708|"Link,l=59"), (dim=100|id=814|"Link,l=60"))
# [61] ((dim=20|id=840|"Site,n=61"), (dim=100|id=814|"Link,l=60"), (dim=100|id=351|"Link,l=61"))
# [62] ((dim=20|id=545|"Site,n=62"), (dim=100|id=351|"Link,l=61"), (dim=100|id=636|"Link,l=62"))
# [63] ((dim=20|id=718|"Site,n=63"), (dim=100|id=636|"Link,l=62"), (dim=100|id=716|"Link,l=63"))
# [64] ((dim=20|id=108|"Site,n=64"), (dim=100|id=716|"Link,l=63"), (dim=100|id=475|"Link,l=64"))
# [65] ((dim=20|id=778|"Site,n=65"), (dim=100|id=475|"Link,l=64"), (dim=100|id=509|"Link,l=65"))
# [66] ((dim=20|id=163|"Site,n=66"), (dim=100|id=509|"Link,l=65"), (dim=100|id=77|"Link,l=66"))
# [67] ((dim=20|id=89|"Site,n=67"), (dim=100|id=77|"Link,l=66"), (dim=100|id=796|"Link,l=67"))
# [68] ((dim=20|id=963|"Site,n=68"), (dim=100|id=796|"Link,l=67"), (dim=100|id=121|"Link,l=68"))
# [69] ((dim=20|id=438|"Site,n=69"), (dim=100|id=121|"Link,l=68"), (dim=100|id=983|"Link,l=69"))
# [70] ((dim=20|id=93|"Site,n=70"), (dim=100|id=983|"Link,l=69"), (dim=100|id=338|"Link,l=70"))
# [71] ((dim=20|id=514|"Site,n=71"), (dim=100|id=338|"Link,l=70"), (dim=100|id=387|"Link,l=71"))
# [72] ((dim=20|id=729|"Site,n=72"), (dim=100|id=387|"Link,l=71"), (dim=100|id=927|"Link,l=72"))
# [73] ((dim=20|id=243|"Site,n=73"), (dim=100|id=927|"Link,l=72"), (dim=100|id=34|"Link,l=73"))
# [74] ((dim=20|id=808|"Site,n=74"), (dim=100|id=34|"Link,l=73"), (dim=100|id=767|"Link,l=74"))
# [75] ((dim=20|id=422|"Site,n=75"), (dim=100|id=767|"Link,l=74"), (dim=100|id=120|"Link,l=75"))
# [76] ((dim=20|id=424|"Site,n=76"), (dim=100|id=120|"Link,l=75"), (dim=100|id=498|"Link,l=76"))
# [77] ((dim=20|id=929|"Site,n=77"), (dim=100|id=498|"Link,l=76"), (dim=100|id=699|"Link,l=77"))
# [78] ((dim=20|id=700|"Site,n=78"), (dim=100|id=699|"Link,l=77"), (dim=100|id=458|"Link,l=78"))
# [79] ((dim=20|id=22|"Site,n=79"), (dim=100|id=458|"Link,l=78"), (dim=100|id=447|"Link,l=79"))
# [80] ((dim=20|id=900|"Site,n=80"), (dim=100|id=447|"Link,l=79"), (dim=100|id=714|"Link,l=80"))
# [81] ((dim=20|id=367|"Site,n=81"), (dim=100|id=714|"Link,l=80"), (dim=100|id=232|"Link,l=81"))
# [82] ((dim=20|id=22|"Site,n=82"), (dim=100|id=232|"Link,l=81"), (dim=100|id=697|"Link,l=82"))
# [83] ((dim=20|id=859|"Site,n=83"), (dim=100|id=697|"Link,l=82"), (dim=100|id=474|"Link,l=83"))
# [84] ((dim=20|id=640|"Site,n=84"), (dim=100|id=474|"Link,l=83"), (dim=100|id=460|"Link,l=84"))
# [85] ((dim=20|id=735|"Site,n=85"), (dim=100|id=460|"Link,l=84"), (dim=100|id=189|"Link,l=85"))
# [86] ((dim=20|id=788|"Site,n=86"), (dim=100|id=189|"Link,l=85"), (dim=100|id=171|"Link,l=86"))
# [87] ((dim=20|id=114|"Site,n=87"), (dim=100|id=171|"Link,l=86"), (dim=100|id=536|"Link,l=87"))
# [88] ((dim=20|id=574|"Site,n=88"), (dim=100|id=536|"Link,l=87"), (dim=100|id=939|"Link,l=88"))
# [89] ((dim=20|id=635|"Site,n=89"), (dim=100|id=939|"Link,l=88"), (dim=100|id=692|"Link,l=89"))
# [90] ((dim=20|id=19|"Site,n=90"), (dim=100|id=692|"Link,l=89"), (dim=100|id=123|"Link,l=90"))
# [91] ((dim=20|id=258|"Site,n=91"), (dim=100|id=123|"Link,l=90"), (dim=100|id=959|"Link,l=91"))
# [92] ((dim=20|id=176|"Site,n=92"), (dim=100|id=959|"Link,l=91"), (dim=100|id=590|"Link,l=92"))
# [93] ((dim=20|id=174|"Site,n=93"), (dim=100|id=590|"Link,l=92"), (dim=100|id=273|"Link,l=93"))
# [94] ((dim=20|id=508|"Site,n=94"), (dim=100|id=273|"Link,l=93"), (dim=100|id=966|"Link,l=94"))
# [95] ((dim=20|id=264|"Site,n=95"), (dim=100|id=966|"Link,l=94"), (dim=34|id=533|"Link,l=95"))
# [96] ((dim=20|id=617|"Site,n=96"), (dim=34|id=533|"Link,l=95"))
# , 0, [0.44362091 0.94728503 … 1.0378788 1.0096155; 0.79567475 0.9502404 … 0.56857857 0.40117688; … ; 1.1136848 1.2759515 … 0.47963844 0.35869955; 2.3182077 2.1397723 … 0.28500798 0.4709143], Options
#   verbosity: Int64 0
#   nsweeps: Int64 15
#   chi_max: Int64 100
#   cutoff: Float64 1.0e-10
#   update_iters: Int64 1
#   dtype: Float64 <: AbstractFloat
#   loss_grad: Loss_Grad_KLD() (function of type Loss_Grad_KLD)
#   bbopt: BBOpt
#   track_cost: Bool false
#   eta: Float64 0.0025
#   rescale: Tuple{Bool, Bool}
#   d: Int64 20
#   aux_basis_dim: Int64 2
#   encoding: Basis
#   train_classes_separately: Bool false
#   encode_classes_separately: Bool false
#   return_encoding_meta_info: Bool false
#   minmax: Bool true
#   exit_early: Bool false
#   sigmoid_transform: Bool false
#   log_level: Int64 0
#   data_bounds: Tuple{Float64, Float64}
# , Any[UnivariateKDE{StepRangeLen{Float64, Base.TwicePrecision{Float64}, Base.TwicePrecision{Float64}, Int64}}(-1.163622917407817:0.001136905634985654:1.163622917407817, [1.749375553861121e-6, 1.8550415724627456e-6, 1.9841267079323543e-6, 2.1380803119086522e-6, 2.3185881857790136e-6, 2.5275857615802977e-6, 2.767272761827755e-6, 3.0401293956705544e-6, 3.3489341462189515e-6, 3.6967832095502473e-6  …  1.8114018332515691e-6, 1.7172892792516325e-6, 1.6431639992819935e-6, 1.5885460024622766e-6, 1.5531305215255031e-6, 1.5367890134898587e-6, 1.5395711969456993e-6, 1.5617081573493508e-6, 1.6036165573773964e-6, 1.6659039958621946e-6]), 0.055509302058334035, 0.999226589369859, [1.0 0.0 … 0.0 0.0; 0.7889947237140468 3.402174727991654 … 0.0 0.0; … ; 0.129801744540877 -14.753223816711696 … -486901.0765455599 0.0; 0.627924665208207 6.088077063008073 … -381574.9248894589 -970007.9871350618]])

# %%
inds.(mps_sl)
# Out:
# 96-element Vector{Tuple{Index{Int64}, Index{Int64}, Vararg{Index{Int64}}}}:
#  ((dim=20|id=690|"Site,n=1"), (dim=15|id=745|"Link,l=1"))
#  ((dim=20|id=221|"Site,n=2"), (dim=15|id=745|"Link,l=1"), (dim=89|id=54|"Link,l=2"))
#  ((dim=20|id=230|"Site,n=3"), (dim=89|id=54|"Link,l=2"), (dim=100|id=391|"Link,l=3"))
#  ((dim=20|id=425|"Site,n=4"), (dim=100|id=391|"Link,l=3"), (dim=100|id=516|"Link,l=4"))
#  ((dim=20|id=376|"Site,n=5"), (dim=100|id=516|"Link,l=4"), (dim=100|id=257|"Link,l=5"))
#  ((dim=20|id=806|"Site,n=6"), (dim=100|id=257|"Link,l=5"), (dim=100|id=919|"Link,l=6"))
#  ((dim=20|id=941|"Site,n=7"), (dim=100|id=919|"Link,l=6"), (dim=100|id=650|"Link,l=7"))
#  ((dim=20|id=837|"Site,n=8"), (dim=100|id=650|"Link,l=7"), (dim=100|id=171|"Link,l=8"))
#  ((dim=20|id=702|"Site,n=9"), (dim=100|id=171|"Link,l=8"), (dim=100|id=666|"Link,l=9"))
#  ((dim=20|id=748|"Site,n=10"), (dim=100|id=666|"Link,l=9"), (dim=100|id=973|"Link,l=10"))
#  ⋮
#  ((dim=20|id=574|"Site,n=88"), (dim=100|id=536|"Link,l=87"), (dim=100|id=939|"Link,l=88"))
#  ((dim=20|id=635|"Site,n=89"), (dim=100|id=939|"Link,l=88"), (dim=100|id=692|"Link,l=89"))
#  ((dim=20|id=19|"Site,n=90"), (dim=100|id=692|"Link,l=89"), (dim=100|id=123|"Link,l=90"))
#  ((dim=20|id=258|"Site,n=91"), (dim=100|id=123|"Link,l=90"), (dim=100|id=959|"Link,l=91"))
#  ((dim=20|id=176|"Site,n=92"), (dim=100|id=959|"Link,l=91"), (dim=100|id=590|"Link,l=92"))
#  ((dim=20|id=174|"Site,n=93"), (dim=100|id=590|"Link,l=92"), (dim=100|id=273|"Link,l=93"))
#  ((dim=20|id=508|"Site,n=94"), (dim=100|id=273|"Link,l=93"), (dim=100|id=966|"Link,l=94"))
#  ((dim=20|id=264|"Site,n=95"), (dim=100|id=966|"Link,l=94"), (dim=34|id=533|"Link,l=95"))
#  ((dim=2|id=669|"f(x)"), (dim=20|id=617|"Site,n=96"), (dim=34|id=533|"Link,l=95"))

# %%
tensor
